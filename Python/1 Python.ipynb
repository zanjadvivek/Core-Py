# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ##VARIABLE
# 1. Variable is a container that holds any value like number, text, collection
# 2. Variable can store one value at a time means it holds the latest value only
# 3. Variables are created in memory

# %%
i= 100
j= 100
i=j=500
print(i)
print(j)
# Out:
# 500
# 500

# %% [markdown]
# ##Concatination

# %%
"hello"  + " world"

x = "hello"  + " world"
print(x)

10 + 10


10 + int("10")

str(10) + "10"
# Out:
# hello world
# '1010'

# %% [markdown]
# ##Interpolation
# Interpolation is technique to replace values of variable in a placeholder/template

# %%
X = 100
print("The value of variable x is :" + str(X))

y = "Hello"
print("The value of variable y is :" + y)
# Out:
# The value of variable x is :100
# The value of variable y is :Hello

# %%
X = 100
y = "Hello"

print("The value of variable x is :" + str(X) + " and value of variable y is:" + y)
print("The value of variable x is : %s" %(X))
print("The value of variable x is : %s and value of variable y is: %s" %(X,y))
# Out:
# The value of variable x is :100 and value of variable y is:Hello
# The value of variable x is : 100
# The value of variable x is : 100 and value of variable y is: Hello

# %%
print("The value of variable x is : {}".format(X))

print("The value of variable x is : {} and value of variable y is: {}".format(X,y))

print("The value of variable x is : {a1} and value of variable y is: {b1}".format(a1=X,b1=y))

print("The value of variable x is : {a1} and value of variable y is: {b1}".format(b1=y,a1=X))
# Out:
# The value of variable x is : 100
# The value of variable x is : 100 and value of variable y is: Hello
# The value of variable x is : 100 and value of variable y is: Hello
# The value of variable x is : 100 and value of variable y is: Hello

# %%
print(f"The value of variable x is : {X}")

print(f"The value of variable x is : {X} and value of variable y is: {y}")
# Out:
# The value of variable x is : 100
# The value of variable x is : 100 and value of variable y is: Hello

# %%
a = 100.516813

print("The value of variable x is : %s" %(a))

print("The value of variable a is : %.2f" %(a))
# Out:
# The value of variable x is : 100.516813
# The value of variable a is : 100.52
